# %%
import seaborn as sns

# %%
iris=sns.load_dataset('Iris.csv')
iris
# Out:
# ---------------------------------------------------------------------------
# gaierror                                  Traceback (most recent call last)
# File c:\Users\LAPTOP\AppData\Local\Programs\Python\Python311\Lib\urllib\request.py:1348, in AbstractHTTPHandler.do_open(self, http_class, req, **http_conn_args)
#    1347 try:
# -> 1348     h.request(req.get_method(), req.selector, req.data, headers,
#    1349               encode_chunked=req.has_header('Transfer-encoding'))
#    1350 except OSError as err: # timeout error
#
# File c:\Users\LAPTOP\AppData\Local\Programs\Python\Python311\Lib\http\client.py:1286, in HTTPConnection.request(self, method, url, body, headers, encode_chunked)
#    1285 """Send a complete request to the server."""
# -> 1286 self._send_request(method, url, body, headers, encode_chunked)
#
# File c:\Users\LAPTOP\AppData\Local\Programs\Python\Python311\Lib\http\client.py:1332, in HTTPConnection._send_request(self, method, url, body, headers, encode_chunked)
# ...

# %%
sns . scatterplot(x=iris.sepal_lenth,y=iris.sepal_width)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# c:\Users\LAPTOP\OneDrive\Desktop\Coding\Python\jupiter\Visulization(seaborn).ipynb Cell 3 line 1
# ----> <a href='vscode-notebook-cell:/c%3A/Users/LAPTOP/OneDrive/Desktop/Coding/Python/jupiter/Visulization%28seaborn%29.ipynb#W2sZmlsZQ%3D%3D?line=0'>1</a> sns . scatterplot(x=iris.sepal_lenth,y=iris.sepal_width)
#
# NameError: name 'iris' is not defined

# %%
sns.displot(iris['sepal_length'])
