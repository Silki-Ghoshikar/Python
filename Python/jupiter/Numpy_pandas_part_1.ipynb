# %%
import numpy as np
l = [1,2,3,4,5]
array=np.array(l)
type(array)
# Out:
# numpy.ndarray

# %%
np.asarray(l)
# Out:
# array([1, 2, 3, 4, 5])

# %%
arr1 = np.array([[1,2,3],[4,5,6]])
array.ndim
# Out:
# 1

# %%
arr1.ndim
# Out:
# 2

# %%
arr1
# Out:
# array([[1, 2, 3],
#        [4, 5, 6]])

# %%
array
# Out:
# array([1, 2, 3, 4, 5])

# %%
arr1
# Out:
# array([[1, 2, 3],
#        [4, 5, 6]])

# %%
np.matrix(l)
# Out:
# matrix([[1, 2, 3, 4, 5]])

# %%
## asanyarray function convert the input data into the array.
mat = np.matrix(l)
np.asanyarray(l)
# Out:
# array([1, 2, 3, 4, 5])

# %%
np.asanyarray(mat)
# Out:
# matrix([[1, 2, 3, 4, 5]])

# %%
a = array
a
# Out:
# array([1, 2, 3, 4, 5])

# %%
array
# Out:
# array([1, 2, 3, 4, 5])

# %%
array[0]=100
array
# Out:
# array([100,   2,   3,   4,   5])

# %%
a
# Out:
# array([100,   2,   3,   4,   5])

# %%
b = np.copy(array)
b
#The copy ( ) return a shllow copy of the list , and deepcopy () return a deep copy of list .
# Out:
# array([100,   2,   3,   4,   5])

# %%
b[0] =347965
b
# This is the shallow copy in which the change in b will not affect the array
# Out:
# array([347965,      2,      3,      4,      5])

# %%
array
# Out:
# array([100,   2,   3,   4,   5])

# %%
np.fromfunction(lambda i, j:i ==j ,(3,3))
# formfunction --> formfunction is a function in python which is used to construct an array in such a way that a given function passed to it exceuted
# Out:
# array([[ True, False, False],
#        [False,  True, False],
#        [False, False,  True]])

# %%
np.fromfunction(lambda i, j:i*j ,(3,3))
# Out:
# array([[0., 0., 0.],
#        [0., 1., 2.],
#        [0., 2., 4.]])

# %%
(i*i for i in range (5))
# Out:
# <generator object <genexpr> at 0x0000020DC2CCDF20>

# %%
list (i* i for i in range (5))
# Out:
# [0, 1, 4, 9, 16]

# %%
iterable = (list (i* i for i in range (5)))
np.fromiter(iterable , float)
# Out:
# array([ 0.,  1.,  4.,  9., 16.])

# %%
arr1
# Out:
# array([[1, 2, 3],
#        [4, 5, 6]])

# %%
array.ndim
# Out:
# 1

# %%
np.fromstring('23 45 56 ',sep = ' ')
# Out:
# array([23., 45., 56.])

# %%
arr1 .ndim
# Out:
# 2

# %%
array.size
# Out:
# 5

# %%
arr1.size
# Out:
# 6

# %%
arr1.shape
# Out:
# (2, 3)

# %%
arr1
# Out:
# array([[1, 2, 3],
#        [4, 5, 6]])

# %%
arr1.dtype
# Out:
# dtype('int32')

# %%
array.dtype
# Out:
# dtype('int32')
